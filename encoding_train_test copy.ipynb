# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('merged_data.csv')

# %%
rfe = ['transcript_id',
'transcript_position',
'sequence',
'gene_id',
'avg_central_mean',
'avg_1+flank_std',
'med_central_std',
'med_central_mean',
'med_1+flank_std',
'std_1-flank_std',
'std_1-flank_mean',
'std_central_std',
'std_central_mean',
'std_1+flank_std',
'std_1+flank_mean',
'label']
df = df[rfe]

# %%
df.shape
# Out:
# (121838, 16)

# %%
df['seq_left'] = df['sequence'].str[0:5]
df['seq_center'] = df['sequence'].str[1:6]
df['seq_right'] = df['sequence'].str[2:7]

# %%
df.head()
# Out:
#      transcript_id  transcript_position sequence          gene_id  \
# 0  ENST00000000233                  244  AAGACCA  ENSG00000004059
# 1  ENST00000000233                  261  CAAACTG  ENSG00000004059
# 2  ENST00000000233                  316  GAAACAG  ENSG00000004059
# 3  ENST00000000233                  332  AGAACAT  ENSG00000004059
# 4  ENST00000000233                  368  AGGACAA  ENSG00000004059
#
#    avg_central_mean  avg_1+flank_std  med_central_std  med_central_mean  \
# 0        125.913514         4.386989            6.650             126.0
# 1        107.889535         3.016599            3.000             108.0
# 2         98.947027         2.087146            3.780              99.5
# 3         97.836500         2.236520            2.635              97.5
# 4        121.954545         4.260253            5.660             122.0
#
#    med_1+flank_std  std_1-flank_std  std_1-flank_mean  std_central_std  \
# 0            3.440         1.843025          4.944365         3.302671
# 1            2.660         1.689167          2.981182         1.237045
# 2            1.910         1.311103          1.492577         0.893481
# 3            2.135         2.459317          3.202963         1.393868
# 4            4.160         2.743228          2.664643         1.753894
#
#    std_central_mean  std_1+flank_std  std_1+flank_mean  label seq_left  \
# 0          2.765244         2.906225          2.522168      0    AAGAC
# 1          3.526528         1.466295          2.492530      0    CAAAC
# 2          3.203816         0.800496          1.484341      0    GAAAC
# 3          1.928009         0.741771          3.494937      0    AGAAC
# 4          2.177236         1.341822          2.379045      0    AGGAC
#
#   seq_center seq_right
# 0      AGACC     GACCA
# 1      AAACT     AACTG
# 2      AAACA     AACAG
# 3      GAACA     AACAT
# 4      GGACA     GACAA

# %%
df_le = df.copy()
label_encoder = LabelEncoder()

seq_data = ['seq_left','seq_center','seq_right']
for seq in seq_data: 
    encoded_labels = label_encoder.fit_transform(df_le[seq])
    df_le[seq] = encoded_labels

df_le.head()
# Out:
#      transcript_id  transcript_position sequence          gene_id  \
# 0  ENST00000000233                  244  AAGACCA  ENSG00000004059
# 1  ENST00000000233                  261  CAAACTG  ENSG00000004059
# 2  ENST00000000233                  316  GAAACAG  ENSG00000004059
# 3  ENST00000000233                  332  AGAACAT  ENSG00000004059
# 4  ENST00000000233                  368  AGGACAA  ENSG00000004059
#
#    avg_central_mean  avg_1+flank_std  med_central_std  med_central_mean  \
# 0        125.913514         4.386989            6.650             126.0
# 1        107.889535         3.016599            3.000             108.0
# 2         98.947027         2.087146            3.780              99.5
# 3         97.836500         2.236520            2.635              97.5
# 4        121.954545         4.260253            5.660             122.0
#
#    med_1+flank_std  std_1-flank_std  std_1-flank_mean  std_central_std  \
# 0            3.440         1.843025          4.944365         3.302671
# 1            2.660         1.689167          2.981182         1.237045
# 2            1.910         1.311103          1.492577         0.893481
# 3            2.135         2.459317          3.202963         1.393868
# 4            4.160         2.743228          2.664643         1.753894
#
#    std_central_mean  std_1+flank_std  std_1+flank_mean  label  seq_left  \
# 0          2.765244         2.906225          2.522168      0         1
# 1          3.526528         1.466295          2.492530      0         6
# 2          3.203816         0.800496          1.484341      0        12
# 3          1.928009         0.741771          3.494937      0         2
# 4          2.177236         1.341822          2.379045      0         3
#
#    seq_center  seq_right
# 0           4         16
# 1           2         10
# 2           0          2
# 3           6          3
# 4           9         12

# %%
df_le = df_le.drop(["sequence"], axis=1)

# %%
df_le.columns
# Out:
# Index(['transcript_id', 'transcript_position', 'gene_id', 'avg_central_mean',
#        'avg_1+flank_std', 'med_central_std', 'med_central_mean',
#        'med_1+flank_std', 'std_1-flank_std', 'std_1-flank_mean',
#        'std_central_std', 'std_central_mean', 'std_1+flank_std',
#        'std_1+flank_mean', 'label', 'seq_left', 'seq_center', 'seq_right'],
#       dtype='object')

# %%
from sklearn.model_selection import GroupShuffleSplit
group_split = GroupShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
train_idx, test_idx = next(group_split.split(df_le, groups=df['gene_id']))

train = df_le.iloc[train_idx]
test = df_le.iloc[test_idx]

# %%
train.shape
# Out:
# (98006, 18)

# %%
test.shape
# Out:
# (23832, 18)

# %%
len(train[train['label'] == 0])
# Out:
# 93715

# %%
len(train[train['label'] == 1])
# Out:
# 4291

# %%
1 - 4332/93138
# Out:
# 0.9534883720930233

# %%
X_train = train.drop(['transcript_id', 'gene_id', 'label'], axis=1)
y_train = train['label']

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(sampling_strategy='auto', random_state=42)
X_resampledtrain, y_resampledtrain = smote.fit_resample(X_train, y_train)

# %%
original_class_counts = y_train.value_counts()
resampled_class_counts = pd.Series(y_resampledtrain).value_counts()

print("Original Class Distribution:")
print(original_class_counts)

print("\nResampled Class Distribution:")
print(resampled_class_counts)
# Out:
# Original Class Distribution:
# label
# 0    93715
# 1     4291
# Name: count, dtype: int64
#
# Resampled Class Distribution:
# label
# 0    93715
# 1    93715
# Name: count, dtype: int64

# %%
transcript_id_train = train['transcript_id']
gene_id_train = train['gene_id']

# %%
resampled_train = pd.DataFrame(data=X_resampledtrain, columns=X_train.columns)
resampled_train['label'] = y_resampledtrain

transcript_id_train.reset_index(drop=True, inplace=True)
gene_id_train.reset_index(drop=True, inplace=True)

resampled_train['transcript_id'] = transcript_id_train
resampled_train['gene_id'] = gene_id_train
resampled_train.to_csv('traindata_rfe.csv', index=False)

# %%
test.to_csv('testdata_rfe.csv', index=False)

# %%
resampled_train.head()
# Out:
#    transcript_position  avg_central_mean  avg_1+flank_std  med_central_std  \
# 0                  244        125.913514         4.386989            6.650
# 1                  261        107.889535         3.016599            3.000
# 2                  316         98.947027         2.087146            3.780
# 3                  332         97.836500         2.236520            2.635
# 4                  368        121.954545         4.260253            5.660
#
#    med_central_mean  med_1+flank_std  std_1-flank_std  std_1-flank_mean  \
# 0             126.0            3.440         1.843025          4.944365
# 1             108.0            2.660         1.689167          2.981182
# 2              99.5            1.910         1.311103          1.492577
# 3              97.5            2.135         2.459317          3.202963
# 4             122.0            4.160         2.743228          2.664643
#
#    std_central_std  std_central_mean  std_1+flank_std  std_1+flank_mean  \
# 0         3.302671          2.765244         2.906225          2.522168
# 1         1.237045          3.526528         1.466295          2.492530
# 2         0.893481          3.203816         0.800496          1.484341
# 3         1.393868          1.928009         0.741771          3.494937
# 4         1.753894          2.177236         1.341822          2.379045
#
#    seq_left  seq_center  seq_right  label    transcript_id          gene_id
# 0         1           4         16      0  ENST00000000233  ENSG00000004059
# 1         6           2         10      0  ENST00000000233  ENSG00000004059
# 2        12           0          2      0  ENST00000000233  ENSG00000004059
# 3         2           6          3      0  ENST00000000233  ENSG00000004059
# 4         3           9         12      0  ENST00000000233  ENSG00000004059

# %%
test.head()
# Out:
#        transcript_id  transcript_position          gene_id  avg_central_mean  \
# 153  ENST00000005257                  470  ENSG00000006451        121.032258
# 154  ENST00000005257                  504  ENSG00000006451        126.029412
# 155  ENST00000005257                  525  ENSG00000006451        125.387097
# 156  ENST00000005257                  600  ENSG00000006451        122.606061
# 157  ENST00000005257                  696  ENSG00000006451        121.965517
#
#      avg_1+flank_std  med_central_std  med_central_mean  med_1+flank_std  \
# 153         2.513839             9.26             121.0            2.390
# 154         2.674206             4.92             126.0            2.315
# 155         3.073226             6.15             126.0            2.880
# 156         3.255455             5.94             122.0            3.030
# 157         3.116897             7.81             122.0            2.820
#
#      std_1-flank_std  std_1-flank_mean  std_central_std  std_central_mean  \
# 153         3.070013          4.203054         1.736880          3.126204
# 154         1.562898          2.673237         1.436917          2.345023
# 155         1.130465          3.727447         2.105785          2.611110
# 156         2.399447          2.938300         2.782057          3.311499
# 157         1.898227          3.906871         2.458343          3.537803
#
#      std_1+flank_std  std_1+flank_mean  label  seq_left  seq_center  seq_right
# 153         0.869722          1.267762      0        11          17         21
# 154         1.113461          1.576460      0         3          11         20
# 155         1.273123          2.040985      0         7           3         14
# 156         1.286042          1.975153      0         3          11         20
# 157         1.348092          1.171399      0        11          17         23
