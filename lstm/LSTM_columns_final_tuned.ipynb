# %%
import pandas as pd
import tensorflow as tf
from tensorflow import keras
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

# %%
## mount drive and retrieve labelled data

from google.colab import drive
drive.mount("/content/drive")

import os
os.chdir("/content/drive/MyDrive/DSA4266_Tundra")
# Out:
# Mounted at /content/drive

# %%
train = pd.read_csv("traindata_rfe.csv")
test = pd.read_csv("testdata_rfe.csv")
# Out:
# <ipython-input-3-a1529cdefe75>:1: DtypeWarning: Columns (16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   train = pd.read_csv("traindata_rfe.csv")

# %%
train.head()
# Out:
#    transcript_position  avg_central_mean  avg_1+flank_std  med_central_std  \
# 0                  244        125.913514         4.386989            6.650
# 1                  261        107.889535         3.016599            3.000
# 2                  316         98.947027         2.087146            3.780
# 3                  332         97.836500         2.236520            2.635
# 4                  368        121.954545         4.260253            5.660
#
#    med_central_mean  med_1+flank_std  std_1-flank_std  std_1-flank_mean  \
# 0             126.0            3.440         1.843025          4.944365
# 1             108.0            2.660         1.689167          2.981182
# 2              99.5            1.910         1.311103          1.492577
# 3              97.5            2.135         2.459317          3.202963
# 4             122.0            4.160         2.743228          2.664643
#
#    std_central_std  std_central_mean  std_1+flank_std  std_1+flank_mean  \
# 0         3.302671          2.765244         2.906225          2.522168
# 1         1.237045          3.526528         1.466295          2.492530
# 2         0.893481          3.203816         0.800496          1.484341
# 3         1.393868          1.928009         0.741771          3.494937
# 4         1.753894          2.177236         1.341822          2.379045
#
#    seq_left  seq_center  seq_right  label    transcript_id          gene_id
# 0         1           4         16      0  ENST00000000233  ENSG00000004059
# 1         6           2         10      0  ENST00000000233  ENSG00000004059
# 2        12           0          2      0  ENST00000000233  ENSG00000004059
# 3         2           6          3      0  ENST00000000233  ENSG00000004059
# 4         3           9         12      0  ENST00000000233  ENSG00000004059

# %%
test.head()
# Out:
#      transcript_id  transcript_position          gene_id  avg_central_mean  \
# 0  ENST00000005257                  470  ENSG00000006451        121.032258
# 1  ENST00000005257                  504  ENSG00000006451        126.029412
# 2  ENST00000005257                  525  ENSG00000006451        125.387097
# 3  ENST00000005257                  600  ENSG00000006451        122.606061
# 4  ENST00000005257                  696  ENSG00000006451        121.965517
#
#    avg_1+flank_std  med_central_std  med_central_mean  med_1+flank_std  \
# 0         2.513839             9.26             121.0            2.390
# 1         2.674206             4.92             126.0            2.315
# 2         3.073226             6.15             126.0            2.880
# 3         3.255455             5.94             122.0            3.030
# 4         3.116897             7.81             122.0            2.820
#
#    std_1-flank_std  std_1-flank_mean  std_central_std  std_central_mean  \
# 0         3.070013          4.203054         1.736880          3.126204
# 1         1.562898          2.673237         1.436917          2.345023
# 2         1.130465          3.727447         2.105785          2.611110
# 3         2.399447          2.938300         2.782057          3.311499
# 4         1.898227          3.906871         2.458343          3.537803
#
#    std_1+flank_std  std_1+flank_mean  label  seq_left  seq_center  seq_right
# 0         0.869722          1.267762      0        11          17         21
# 1         1.113461          1.576460      0         3          11         20
# 2         1.273123          2.040985      0         7           3         14
# 3         1.286042          1.975153      0         3          11         20
# 4         1.348092          1.171399      0        11          17         23

# %%
X_train = train.drop(['transcript_id', 'gene_id', 'label'], axis=1)
y_train = train['label']
X_test = test.drop(['transcript_id', 'gene_id', 'label'], axis=1)
y_test = test['label']

# %%
y_train.value_counts()
# Out:
# 0    93715
# 1    93715
# Name: label, dtype: int64

# %%
from sklearn import preprocessing
scaler = preprocessing.MinMaxScaler()
d = scaler.fit_transform(X_train)
normalised_X_train = pd.DataFrame(d, columns=X_train.columns)
X_train = normalised_X_train

# %%
d = scaler.fit_transform(X_test)
normalised_X_test = pd.DataFrame(d, columns=X_test.columns)
X_test = normalised_X_test

# %%
X_train.shape
# Out:
# (187430, 15)

# %%
normalised_X_train.head()
# Out:
#    transcript_position  avg_central_mean  avg_1+flank_std  med_central_std  \
# 0             0.012869          0.774042         0.287885         0.463500
# 1             0.013777          0.410623         0.157972         0.142480
# 2             0.016714          0.230314         0.069860         0.211082
# 3             0.017568          0.207922         0.084021         0.110378
# 4             0.019491          0.694217         0.275871         0.376429
#
#    med_central_mean  med_1+flank_std  std_1-flank_std  std_1-flank_mean  \
# 0          0.781312         0.201650         0.048485          0.280016
# 1          0.423459         0.130156         0.043891          0.152029
# 2          0.254473         0.061412         0.032605          0.054982
# 3          0.214712         0.082035         0.066883          0.166488
# 4          0.701789         0.267644         0.075359          0.131393
#
#    std_central_std  std_central_mean  std_1+flank_std  std_1+flank_mean  \
# 0         0.101848          0.226398         0.090561          0.146461
# 1         0.033255          0.310842         0.042812          0.144293
# 2         0.021846          0.275046         0.020733          0.070529
# 3         0.038463          0.133529         0.018786          0.217634
# 4         0.050418          0.161175         0.038684          0.135990
#
#    seq_left  seq_center  seq_right
# 0  0.043478    0.235294   0.695652
# 1  0.260870    0.117647   0.434783
# 2  0.521739    0.000000   0.086957
# 3  0.086957    0.352941   0.130435
# 4  0.130435    0.529412   0.521739

# %%
normalised_X_test.head()
# Out:
#    transcript_position  avg_central_mean  avg_1+flank_std  med_central_std  \
# 0             0.054772          0.689752         0.111903         0.727019
# 1             0.058768          0.791245         0.128262         0.324048
# 2             0.061236          0.778200         0.168967         0.438254
# 3             0.070052          0.721716         0.187557         0.418756
# 4             0.081335          0.708707         0.173422         0.592386
#
#    med_central_mean  med_1+flank_std  std_1-flank_std  std_1-flank_mean  \
# 0          0.693878         0.107848         0.189319          0.254995
# 1          0.795918         0.100253         0.087639          0.142416
# 2          0.795918         0.157468         0.058464          0.219995
# 3          0.714286         0.172658         0.144078          0.161922
# 4          0.714286         0.151392         0.110263          0.233199
#
#    std_central_std  std_central_mean  std_1+flank_std  std_1+flank_mean  \
# 0         0.077564          0.365202         0.032594          0.026947
# 1         0.062153          0.252199         0.044891          0.043219
# 2         0.096518          0.290691         0.052945          0.067706
# 3         0.131265          0.392006         0.053597          0.064235
# 4         0.114632          0.424743         0.056727          0.021868
#
#    seq_left  seq_center  seq_right
# 0  0.478261    1.000000   0.913043
# 1  0.130435    0.647059   0.869565
# 2  0.304348    0.176471   0.608696
# 3  0.130435    0.647059   0.869565
# 4  0.478261    1.000000   1.000000

# %%
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import SimpleRNN, Dense
# input_sequence_length = X_train.shape[1]
# input_feature_dimension = 1
# output_dimension = 1

# model = Sequential()
# model.add(SimpleRNN(units=64, input_shape=(input_sequence_length, input_feature_dimension), activation='relu'))
# model.add(Dense(units=output_dimension, activation='softmax'))

# %%
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import LSTM, Dense
# input_sequence_length = X_train.shape[1]
# input_feature_dimension = 1
# output_dimension = 1
# model = Sequential()
# model.add(LSTM(units=64, input_shape=(input_sequence_length, input_feature_dimension), activation='relu', return_sequences=True))
# model.add(LSTM(units=32,activation='relu'))
# model.add(Dense(units=output_dimension, activation='sigmoid'))

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import load_model
from sklearn.metrics import roc_auc_score

# Define a function to create and train an LSTM model
def create_lstm_model(units, dropout_rate, learning_rate):
    model = Sequential()
    model.add(LSTM(units, input_shape=(X_train.shape[1], 1)))
    model.add(Dropout(dropout_rate))
    model.add(Dense(1, activation='sigmoid'))

    optimizer = Adam(learning_rate=learning_rate)
    model.compile(loss='binary_crossentropy', optimizer=optimizer)

    return model

# Hyperparameter tuning
best_model = None
best_roc = 0.0

for units in [32,64,128]:
    for dropout_rate in [0.35, 0.4, 0.45]:
        for learning_rate in [0.008, 0.01]:
            model = create_lstm_model(units, dropout_rate, learning_rate)

            # Train the model
            early_stopping = EarlyStopping(patience=5, restore_best_weights=True)
            model.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_test, y_test), callbacks=[early_stopping], verbose=1)

            # Evaluate the model
            y_pred = model.predict(X_test)
            roc = roc_auc_score(y_test, y_pred)

            # Save the best model
            if roc > best_roc:
                best_roc = roc
                if best_model is not None:
                    best_model.save('best_model.h5')
                best_model = model

            print(f"Units: {units}, Dropout: {dropout_rate}, Learning Rate: {learning_rate}, AUC ROC: {roc}")

# Load the best model for further evaluation
best_model = load_model('best_model.h5')
y_test_pred = best_model.predict(X_test)
test_auc_roc = roc_auc_score(y_test, y_test_pred)
print(f"Test AUC-ROC of the best model: {test_auc_roc}")
# Out:
# Epoch 1/20
# 5858/5858 [==============================] - 44s 7ms/step - loss: 0.4023 - val_loss: 0.3117
# Epoch 2/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.3346 - val_loss: 0.2398
# Epoch 3/20
# 5858/5858 [==============================] - 29s 5ms/step - loss: 0.3124 - val_loss: 0.2128
# Epoch 4/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2972 - val_loss: 0.2132
# Epoch 5/20
# 5858/5858 [==============================] - 32s 5ms/step - loss: 0.2868 - val_loss: 0.2212
# Epoch 6/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2780 - val_loss: 0.1950
# Epoch 7/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2685 - val_loss: 0.2157
# Epoch 8/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2622 - val_loss: 0.2112
# Epoch 9/20
# 5858/5858 [==============================] - 32s 5ms/step - loss: 0.2566 - val_loss: 0.2072
# Epoch 10/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2525 - val_loss: 0.1847
# Epoch 11/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2493 - val_loss: 0.2017
# Epoch 12/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2459 - val_loss: 0.1935
# Epoch 13/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2428 - val_loss: 0.2159
# Epoch 14/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2403 - val_loss: 0.2306
# Epoch 15/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2396 - val_loss: 0.2040
# 745/745 [==============================] - 2s 2ms/step
# Units: 32, Dropout: 0.35, Learning Rate: 0.008, AUC ROC: 0.8652210057328611
# Epoch 1/20
# 5858/5858 [==============================] - 33s 5ms/step - loss: 0.4030 - val_loss: 0.2415
# Epoch 2/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.3387 - val_loss: 0.2200
# Epoch 3/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.3138 - val_loss: 0.2358
# Epoch 4/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2982 - val_loss: 0.1951
# Epoch 5/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2864 - val_loss: 0.1861
# Epoch 6/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2764 - val_loss: 0.1868
# Epoch 7/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2674 - val_loss: 0.1728
# Epoch 8/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2596 - val_loss: 0.1855
# Epoch 9/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2526 - val_loss: 0.1927
# Epoch 10/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2484 - val_loss: 0.1915
# Epoch 11/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2451 - val_loss: 0.1796
# Epoch 12/20
# 5858/5858 [==============================] - 32s 5ms/step - loss: 0.2422 - val_loss: 0.1886
# 745/745 [==============================] - 3s 3ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Units: 32, Dropout: 0.35, Learning Rate: 0.01, AUC ROC: 0.8727974831618088
# Epoch 1/20
# 5858/5858 [==============================] - 32s 5ms/step - loss: 0.4027 - val_loss: 0.3345
# Epoch 2/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.3395 - val_loss: 0.3034
# Epoch 3/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.3161 - val_loss: 0.2250
# Epoch 4/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2964 - val_loss: 0.2259
# Epoch 5/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2845 - val_loss: 0.2107
# Epoch 6/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2726 - val_loss: 0.2483
# Epoch 7/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2657 - val_loss: 0.2039
# Epoch 8/20
# 5858/5858 [==============================] - 32s 6ms/step - loss: 0.2589 - val_loss: 0.2429
# Epoch 9/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2534 - val_loss: 0.1907
# Epoch 10/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2491 - val_loss: 0.2002
# Epoch 11/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2450 - val_loss: 0.2259
# Epoch 12/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2417 - val_loss: 0.1801
# Epoch 13/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2362 - val_loss: 0.1863
# Epoch 14/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2326 - val_loss: 0.1764
# Epoch 15/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2299 - val_loss: 0.1978
# Epoch 16/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2289 - val_loss: 0.1989
# Epoch 17/20
# 5858/5858 [==============================] - 32s 5ms/step - loss: 0.2246 - val_loss: 0.1901
# Epoch 18/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2240 - val_loss: 0.1749
# Epoch 19/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2205 - val_loss: 0.1834
# Epoch 20/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2195 - val_loss: 0.1977
# 745/745 [==============================] - 2s 2ms/step
# Units: 32, Dropout: 0.4, Learning Rate: 0.008, AUC ROC: 0.8470398652527042
# Epoch 1/20
# 5858/5858 [==============================] - 33s 5ms/step - loss: 0.4043 - val_loss: 0.2654
# Epoch 2/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.3266 - val_loss: 0.2198
# Epoch 3/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.3073 - val_loss: 0.1921
# Epoch 4/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2914 - val_loss: 0.1979
# Epoch 5/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2783 - val_loss: 0.1803
# Epoch 6/20
# 5858/5858 [==============================] - 32s 5ms/step - loss: 0.2707 - val_loss: 0.1986
# Epoch 7/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2637 - val_loss: 0.1608
# Epoch 8/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2577 - val_loss: 0.1823
# Epoch 9/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2523 - val_loss: 0.1749
# Epoch 10/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2472 - val_loss: 0.1778
# Epoch 11/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2431 - val_loss: 0.1800
# Epoch 12/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2388 - val_loss: 0.1780
# 745/745 [==============================] - 2s 2ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Units: 32, Dropout: 0.4, Learning Rate: 0.01, AUC ROC: 0.8730374587100345
# Epoch 1/20
# 5858/5858 [==============================] - 34s 5ms/step - loss: 0.4064 - val_loss: 0.3915
# Epoch 2/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.3427 - val_loss: 0.2656
# Epoch 3/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.3236 - val_loss: 0.2404
# Epoch 4/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.3102 - val_loss: 0.2123
# Epoch 5/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.3001 - val_loss: 0.2000
# Epoch 6/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2919 - val_loss: 0.2228
# Epoch 7/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2853 - val_loss: 0.2197
# Epoch 8/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2806 - val_loss: 0.2104
# Epoch 9/20
# 5858/5858 [==============================] - 32s 5ms/step - loss: 0.2753 - val_loss: 0.2060
# Epoch 10/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2709 - val_loss: 0.2010
# 745/745 [==============================] - 2s 2ms/step
# Units: 32, Dropout: 0.45, Learning Rate: 0.008, AUC ROC: 0.8607074889376307
# Epoch 1/20
# 5858/5858 [==============================] - 35s 6ms/step - loss: 0.4058 - val_loss: 0.4325
# Epoch 2/20
# 5858/5858 [==============================] - 32s 6ms/step - loss: 0.3419 - val_loss: 0.3287
# Epoch 3/20
# 5858/5858 [==============================] - 32s 5ms/step - loss: 0.3157 - val_loss: 0.2652
# Epoch 4/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2995 - val_loss: 0.2012
# Epoch 5/20
# 5858/5858 [==============================] - 32s 5ms/step - loss: 0.2882 - val_loss: 0.2054
# Epoch 6/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2795 - val_loss: 0.1897
# Epoch 7/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2745 - val_loss: 0.1773
# Epoch 8/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2689 - val_loss: 0.2039
# Epoch 9/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2618 - val_loss: 0.2081
# Epoch 10/20
# 5858/5858 [==============================] - 33s 6ms/step - loss: 0.2581 - val_loss: 0.1899
# Epoch 11/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2527 - val_loss: 0.1822
# Epoch 12/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2501 - val_loss: 0.1767
# Epoch 13/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2461 - val_loss: 0.1737
# Epoch 14/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2426 - val_loss: 0.1918
# Epoch 15/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2396 - val_loss: 0.2208
# Epoch 16/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2378 - val_loss: 0.1565
# Epoch 17/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2351 - val_loss: 0.1713
# Epoch 18/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2321 - val_loss: 0.1821
# Epoch 19/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2420 - val_loss: 0.1629
# Epoch 20/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2294 - val_loss: 0.1741
# 745/745 [==============================] - 2s 2ms/step
# Units: 32, Dropout: 0.45, Learning Rate: 0.01, AUC ROC: 0.8535853801302185
# Epoch 1/20
# 5858/5858 [==============================] - 32s 5ms/step - loss: 0.3899 - val_loss: 0.2861
# Epoch 2/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.3212 - val_loss: 0.2080
# Epoch 3/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2981 - val_loss: 0.1947
# Epoch 4/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2791 - val_loss: 0.1849
# Epoch 5/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2628 - val_loss: 0.1916
# Epoch 6/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2505 - val_loss: 0.1845
# Epoch 7/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2401 - val_loss: 0.1847
# Epoch 8/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2320 - val_loss: 0.1775
# Epoch 9/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2243 - val_loss: 0.1912
# Epoch 10/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2201 - val_loss: 0.1843
# Epoch 11/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2131 - val_loss: 0.1931
# Epoch 12/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2090 - val_loss: 0.1860
# Epoch 13/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2041 - val_loss: 0.1774
# Epoch 14/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2042 - val_loss: 0.2089
# Epoch 15/20
# 5858/5858 [==============================] - 29s 5ms/step - loss: 0.1952 - val_loss: 0.1884
# Epoch 16/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.1938 - val_loss: 0.2039
# Epoch 17/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.6818 - val_loss: 0.6415
# Epoch 18/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.6198 - val_loss: 0.6546
# 745/745 [==============================] - 2s 2ms/step
# Units: 64, Dropout: 0.35, Learning Rate: 0.008, AUC ROC: 0.8467130920217285
# Epoch 1/20
# 5858/5858 [==============================] - 33s 5ms/step - loss: 0.3813 - val_loss: 0.3136
# Epoch 2/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.3197 - val_loss: 0.1774
# Epoch 3/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2979 - val_loss: 0.1638
# Epoch 4/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2831 - val_loss: 0.1861
# Epoch 5/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2715 - val_loss: 0.1796
# Epoch 6/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2601 - val_loss: 0.1765
# Epoch 7/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2526 - val_loss: 0.1841
# Epoch 8/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2914 - val_loss: 0.5229
# 745/745 [==============================] - 2s 2ms/step
# Units: 64, Dropout: 0.35, Learning Rate: 0.01, AUC ROC: 0.8650043378330645
# Epoch 1/20
# 5858/5858 [==============================] - 35s 5ms/step - loss: 0.3962 - val_loss: 0.4420
# Epoch 2/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.3236 - val_loss: 0.2387
# Epoch 3/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.3000 - val_loss: 0.2217
# Epoch 4/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2828 - val_loss: 0.1922
# Epoch 5/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2671 - val_loss: 0.1988
# Epoch 6/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2538 - val_loss: 0.1784
# Epoch 7/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2427 - val_loss: 0.1842
# Epoch 8/20
# 5858/5858 [==============================] - 29s 5ms/step - loss: 0.2371 - val_loss: 0.1888
# Epoch 9/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2279 - val_loss: 0.2002
# Epoch 10/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2252 - val_loss: 0.2007
# Epoch 11/20
# 5858/5858 [==============================] - 32s 5ms/step - loss: 0.2173 - val_loss: 0.1813
# 745/745 [==============================] - 3s 3ms/step
# Units: 64, Dropout: 0.4, Learning Rate: 0.008, AUC ROC: 0.8544557250147976
# Epoch 1/20
# 5858/5858 [==============================] - 34s 5ms/step - loss: 0.3837 - val_loss: 0.2952
# Epoch 2/20
# 5858/5858 [==============================] - 33s 6ms/step - loss: 0.3173 - val_loss: 0.1763
# Epoch 3/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2976 - val_loss: 0.1888
# Epoch 4/20
# 5858/5858 [==============================] - 32s 5ms/step - loss: 0.2809 - val_loss: 0.1773
# Epoch 5/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2673 - val_loss: 0.2074
# Epoch 6/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2557 - val_loss: 0.1803
# Epoch 7/20
# 5858/5858 [==============================] - 32s 5ms/step - loss: 0.2455 - val_loss: 0.1739
# Epoch 8/20
# 5858/5858 [==============================] - 32s 5ms/step - loss: 0.2367 - val_loss: 0.2038
# Epoch 9/20
# 5858/5858 [==============================] - 33s 6ms/step - loss: 0.2296 - val_loss: 0.2069
# Epoch 10/20
# 5858/5858 [==============================] - 32s 5ms/step - loss: 0.2448 - val_loss: 0.1970
# Epoch 11/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2360 - val_loss: 0.1903
# Epoch 12/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2198 - val_loss: 0.2136
# 745/745 [==============================] - 2s 2ms/step
# Units: 64, Dropout: 0.4, Learning Rate: 0.01, AUC ROC: 0.8681162072362454
# Epoch 1/20
# 5858/5858 [==============================] - 34s 5ms/step - loss: 0.4017 - val_loss: 0.2652
# Epoch 2/20
# 5858/5858 [==============================] - 32s 5ms/step - loss: 0.3220 - val_loss: 0.2118
# Epoch 3/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2994 - val_loss: 0.1842
# Epoch 4/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2835 - val_loss: 0.1958
# Epoch 5/20
# 5858/5858 [==============================] - 32s 5ms/step - loss: 0.2710 - val_loss: 0.1699
# Epoch 6/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2588 - val_loss: 0.1893
# Epoch 7/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2512 - val_loss: 0.1827
# Epoch 8/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2440 - val_loss: 0.1869
# Epoch 9/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2364 - val_loss: 0.1892
# Epoch 10/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2305 - val_loss: 0.1962
# 745/745 [==============================] - 2s 2ms/step
# Units: 64, Dropout: 0.45, Learning Rate: 0.008, AUC ROC: 0.8658933288363867
# Epoch 1/20
# 5858/5858 [==============================] - 32s 5ms/step - loss: 0.3952 - val_loss: 0.2045
# Epoch 2/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.3186 - val_loss: 0.2526
# Epoch 3/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2966 - val_loss: 0.2266
# Epoch 4/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2810 - val_loss: 0.1972
# Epoch 5/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2684 - val_loss: 0.2030
# Epoch 6/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2600 - val_loss: 0.1897
# Epoch 7/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2499 - val_loss: 0.1798
# Epoch 8/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2418 - val_loss: 0.1835
# Epoch 9/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2364 - val_loss: 0.1728
# Epoch 10/20
# 5858/5858 [==============================] - 29s 5ms/step - loss: 0.2316 - val_loss: 0.1739
# Epoch 11/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2263 - val_loss: 0.1702
# Epoch 12/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2234 - val_loss: 0.1848
# Epoch 13/20
# 5858/5858 [==============================] - 32s 5ms/step - loss: 0.2308 - val_loss: 0.1766
# Epoch 14/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2217 - val_loss: 0.1930
# Epoch 15/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2291 - val_loss: 0.1842
# Epoch 16/20
# 5858/5858 [==============================] - 29s 5ms/step - loss: 0.2407 - val_loss: 0.1699
# Epoch 17/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2842 - val_loss: 0.1846
# Epoch 18/20
# 5858/5858 [==============================] - 29s 5ms/step - loss: 0.9533 - val_loss: 0.6518
# Epoch 19/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.6848 - val_loss: 0.6743
# Epoch 20/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.6893 - val_loss: 0.5540
# 745/745 [==============================] - 2s 3ms/step
# Units: 64, Dropout: 0.45, Learning Rate: 0.01, AUC ROC: 0.566169127307942
# Epoch 1/20
# 5858/5858 [==============================] - 32s 5ms/step - loss: 0.3897 - val_loss: 0.2380
# Epoch 2/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.3182 - val_loss: 0.1966
# Epoch 3/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2923 - val_loss: 0.1874
# Epoch 4/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2744 - val_loss: 0.1835
# Epoch 5/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2599 - val_loss: 0.1770
# Epoch 6/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2490 - val_loss: 0.1774
# Epoch 7/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2520 - val_loss: 0.2101
# Epoch 8/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2667 - val_loss: 0.1844
# Epoch 9/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2329 - val_loss: 0.1781
# Epoch 10/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2226 - val_loss: 0.2008
# 745/745 [==============================] - 2s 2ms/step
# Units: 128, Dropout: 0.35, Learning Rate: 0.008, AUC ROC: 0.8614200876576417
# Epoch 1/20
# 5858/5858 [==============================] - 35s 6ms/step - loss: 0.3788 - val_loss: 0.2384
# Epoch 2/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.3143 - val_loss: 0.2252
# Epoch 3/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2900 - val_loss: 0.2087
# Epoch 4/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2723 - val_loss: 0.1868
# Epoch 5/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2585 - val_loss: 0.1712
# Epoch 6/20
# 5858/5858 [==============================] - 32s 5ms/step - loss: 0.2446 - val_loss: 0.1942
# Epoch 7/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2358 - val_loss: 0.1919
# Epoch 8/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.6085 - val_loss: 0.9858
# Epoch 9/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.6925 - val_loss: 0.6783
# Epoch 10/20
# 5858/5858 [==============================] - 33s 6ms/step - loss: 0.6533 - val_loss: 0.5959
# 745/745 [==============================] - 3s 2ms/step
# Units: 128, Dropout: 0.35, Learning Rate: 0.01, AUC ROC: 0.8636464901739429
# Epoch 1/20
# 5858/5858 [==============================] - 32s 5ms/step - loss: 0.3895 - val_loss: 0.2987
# Epoch 2/20
# 5858/5858 [==============================] - 32s 5ms/step - loss: 0.3229 - val_loss: 0.2114
# Epoch 3/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2976 - val_loss: 0.2423
# Epoch 4/20
# 5858/5858 [==============================] - 32s 5ms/step - loss: 0.2802 - val_loss: 0.2152
# Epoch 5/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2650 - val_loss: 0.1826
# Epoch 6/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2505 - val_loss: 0.1727
# Epoch 7/20
# 5858/5858 [==============================] - 32s 5ms/step - loss: 0.4251 - val_loss: 0.5655
# Epoch 8/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.4143 - val_loss: 0.1965
# Epoch 9/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.3287 - val_loss: 0.2733
# Epoch 10/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2886 - val_loss: 0.1687
# Epoch 11/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2528 - val_loss: 0.1629
# Epoch 12/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2322 - val_loss: 0.1755
# Epoch 13/20
# 5858/5858 [==============================] - 32s 6ms/step - loss: 0.2186 - val_loss: 0.1744
# Epoch 14/20
# 5858/5858 [==============================] - 48s 8ms/step - loss: 0.2831 - val_loss: 0.2483
# Epoch 15/20
# 5858/5858 [==============================] - 32s 5ms/step - loss: 0.2846 - val_loss: 0.1968
# Epoch 16/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2326 - val_loss: 0.1597
# Epoch 17/20
# 5858/5858 [==============================] - 35s 6ms/step - loss: 0.2137 - val_loss: 0.1641
# Epoch 18/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2031 - val_loss: 0.1690
# Epoch 19/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2077 - val_loss: 0.1732
# Epoch 20/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.7210 - val_loss: 0.6571
# 745/745 [==============================] - 2s 2ms/step
# Units: 128, Dropout: 0.4, Learning Rate: 0.008, AUC ROC: 0.6317481981882536
# Epoch 1/20
# 5858/5858 [==============================] - 33s 5ms/step - loss: 0.3850 - val_loss: 0.2187
# Epoch 2/20
# 5858/5858 [==============================] - 33s 6ms/step - loss: 0.3173 - val_loss: 0.1840
# Epoch 3/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2919 - val_loss: 0.1729
# Epoch 4/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2734 - val_loss: 0.2124
# Epoch 5/20
# 5858/5858 [==============================] - 32s 5ms/step - loss: 0.4465 - val_loss: 0.2845
# Epoch 6/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.3627 - val_loss: 0.1792
# Epoch 7/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.3286 - val_loss: 0.1924
# Epoch 8/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.4212 - val_loss: 0.4513
# 745/745 [==============================] - 2s 2ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Units: 128, Dropout: 0.4, Learning Rate: 0.01, AUC ROC: 0.8734102878543062
# Epoch 1/20
# 5858/5858 [==============================] - 33s 5ms/step - loss: 0.3889 - val_loss: 0.2198
# Epoch 2/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.3187 - val_loss: 0.2300
# Epoch 3/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2916 - val_loss: 0.1866
# Epoch 4/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2739 - val_loss: 0.1710
# Epoch 5/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2583 - val_loss: 0.1793
# Epoch 6/20
# 5858/5858 [==============================] - 32s 6ms/step - loss: 0.2469 - val_loss: 0.1918
# Epoch 7/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2371 - val_loss: 0.1830
# Epoch 8/20
# 5858/5858 [==============================] - 29s 5ms/step - loss: 0.2287 - val_loss: 0.1734
# Epoch 9/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2250 - val_loss: 0.1918
# 745/745 [==============================] - 2s 2ms/step
# Units: 128, Dropout: 0.45, Learning Rate: 0.008, AUC ROC: 0.8603540890490898
# Epoch 1/20
# 5858/5858 [==============================] - 33s 5ms/step - loss: 0.3978 - val_loss: 0.3032
# Epoch 2/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.3204 - val_loss: 0.1740
# Epoch 3/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2936 - val_loss: 0.1874
# Epoch 4/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.2738 - val_loss: 0.1708
# Epoch 5/20
# 5858/5858 [==============================] - 31s 5ms/step - loss: 0.2905 - val_loss: 0.1786
# Epoch 6/20
# 5858/5858 [==============================] - 29s 5ms/step - loss: 0.4975 - val_loss: 0.4268
# Epoch 7/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.4237 - val_loss: 0.2434
# Epoch 8/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.3804 - val_loss: 0.2946
# Epoch 9/20
# 5858/5858 [==============================] - 30s 5ms/step - loss: 0.3529 - val_loss: 0.2350
# 745/745 [==============================] - 2s 2ms/step
# Units: 128, Dropout: 0.45, Learning Rate: 0.01, AUC ROC: 0.8619135198979445
# 745/745 [==============================] - 2s 2ms/step
# Test AUC-ROC of the best model: 0.8730374587100345

# %%
from sklearn.metrics import classification_report

y_pred = best_model.predict(X_test)
y_pred_classes = (y_pred > 0.5).astype(int)

print(classification_report(y_test, y_pred_classes))
# Out:
# 745/745 [==============================] - 2s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97     22648
#            1       0.45      0.44      0.45      1184
#
#     accuracy                           0.95     23832
#    macro avg       0.71      0.71      0.71     23832
# weighted avg       0.95      0.95      0.95     23832

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

y_pred_probs = best_model.predict(X_test).ravel()

fpr, tpr, thresholds = roc_curve(y_test, y_pred_probs)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(10, 7))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')  # Diagonal line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# 745/745 [==============================] - 2s 2ms/step

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import average_precision_score

# Calculate ROC AUC
roc_auc = roc_auc_score(y_test, y_pred_classes)

# Calculate PR AUC
pr_auc = average_precision_score(y_test, y_pred_classes)
pr_auc
# Out:
# 0.22734767668009567

# %%
import joblib
joblib.dump(best_model, 'best_lstm_tuned.pkl')
# Out:
# ['bext_lstm_tuned.pkl']
